-- %%
%python
Data Warehouse (ACID)
Data Lakes

Lakehouse

-- %%
%python
delta, iceberg, hudi == ACID


Data ( Parquet file format)
+ 
Metadata layer

-- %% [markdown]
-- Delta Lake (by default)
-- 1. CTAS create table
-- 2. UI
-- 3. pyspark
-- 4. python

-- %%
%python
Internals of delta lake
 parquet (data)
 +
 _delta_logs (metadata)
 1. crc
 2. json (history command)

-- %%
%sql
use catalog dev;
use schema naval;

-- %%
%sql
create table alpha(id int, name string, city string);

-- %%
%sql
desc extended alpha

-- %%
desc detail alpha

-- %%
select * from alpha

-- %%
desc history alpha

-- %%
insert into alpha values (1, 'Naval', 'Solapur')

-- %%
insert into alpha values (2, 'Rahul', 'Banglore'),(3,'Nikita','Pune')

-- %%
select * from alpha

-- %%
create table beta(order_id int) using iceberg

-- %%
insert into dev.naval.alpha values (id,your_name, your_city)

-- %% [markdown]
-- ### Time Travel

-- %%
select * from dev.naval.alpha version as of 28

-- %%
select * from dev.naval.alpha timestamp as of '2026-09-07T05:03:22.000+00:00'

-- %%
delete from dev.naval.alpha

-- %% [markdown]
-- #### restore

-- %%
restore table dev.naval.alpha to version as of 28
