-- %%
Managed Table.
table in catalog + metada (data(parquet + delta_logs (logs ))) in default location 

create table tblname (id int)

DROP: you loose everything : table in catalog + metada (data(parquet + delta_logs (logs ))) in default location ***

Unmanaged table (External Table)
create tbale tblname (id int) location 'adls:'

table in catalog + metada (data(parquet + delta_logs (logs ))) in user's location 

DROP: table in catalog is dropped but metadata is untouched

-- %%
create table dev.naval.alpha_e (id int) location 's3://jpmctraining/axa/naval/alphae'

-- %%
create table dev.yourname.alpha_e (id int) location 's3://jpmctraining/axa/yourname/alphae'

-- %%
insert into dev.naval.alpha_e values (1),(2)

-- %%
drop table dev.naval.alpha_

-- %%
drop table dev.naval.alpha_e

-- %%
select * from delta.`s3://jpmctraining/axa/naval/alphae`

-- %%
undrop table dev.naval.alpha

--rentention period only till 7 days

-- %%
undrop table dev.naval.alpha_e
