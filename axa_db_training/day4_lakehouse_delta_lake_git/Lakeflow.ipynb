-- %%
Data Ingestion Methods 
1. Batch (Full Load) (CTAS, PySpark) (lakeflow spark declerative pipelines )
2. Incremental (CTAS, PySpark), (SQL - COPY INTO) () lakeflow spark declerative pipelines )
3. Streaming (CTAS, PySpark), (SQL - COPY INTO) (python, spark- Apache Spark Structured Streaming), (python, spark, structure stremaing- Autoloader (handle schema change)) SQL-- (lakeflow spark declerative pipelines (Delta live table(DLT)))

-- %%
Lakeflow: Databricks Unified feature for Data Engineering (Ingestion, Transformation ,Orchestration)
4 core components

1. Lakeflow Connect :(Data Ingestion) (Ingesting, Migration from diferenet Sources ( Apps, databases, dw, cloud etc etc ))
2. Lakeflow Designer: (Visual Data Prep): (NO code tool for transformation )( BI, DA ) (DONE)
3. Lakeflow Spark Declerative pipelines: (Transformation, heavy code, python or SQL) (DLT) (DONE)
4. Lakeflow Jobs : (Orchestration) (Orchestrate all the above) (workflow) (DONE)

-- %%
patient_id, patient_name, doctor, remark

schema got changed (new col, drop col, datatype, col name etc )
patient_id, patient_name, doctor, bp, hr, remark
