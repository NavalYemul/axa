# %%
Reader API 

df=spark.read.csv("path")

# %%
# %sql
select *, current_timestamp() from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

# %%
Lazy Evalution 

Transformations (Logical plan )
1. spark.read
2. filter

Actions  (execution plan)
1. display/ show
2. write

# %%
from pyspark.sql.functions import *

# %%
#reader_api
df_income=spark.read.csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)

# %%
#writer_api
df_income.write.saveAsTable("dev.naval.adult_income_pyspark")

# %%
df_income=spark.read.csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)
df_income.write.mode("overwrite").saveAsTable("dev.naval.adult_income_pyspark")

# %%
(
spark
 .read
 .csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)
 .write
 .mode("overwrite")
 .saveAsTable("dev.naval.adult_income_pyspark")
 )

# %%
df=spark.read.table("dev.naval.adult_income_pyspark")

# %%
# %sql
select * from dev.naval.adult_income_pyspark

# %%
df1=df_income.withColumn("ingestion_ts",current_timestamp())

# %%
df_income.withColumn("ingestion_ts",current_timestamp()).display()

# %%
df_income.filter("workclass='Private'")

# %%
df_income.filter("workclass='Private'").explain(True)

# %%
df_income.filter("workclass='Private'").display()

# %%
df_income.display()

# %% [markdown]
# ## Transformations
#
# data frame functions
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/dataframe.html
# - select
# - withColumnRenamed
# - withColumnsRenamed
# - filter
# - withColumn
#
#
# Functions
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html
# - col
# - current_timestamp, current_date
# - lit
# - file_path
# - upper, lower

# %%
#reader_api
df_income=spark.read.csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)

# %%
# %sql
select c1, c2, c3 from table

# %%
df_income.select("age","workclass","race")

# %%
df_income.select("*")

# %%
df_1=df_income.select("age","workclass","race")

# %%
df_renamed=df_income.withColumnRenamed("capital.gain","captial_gain").withColumnRenamed("capital.loss","capital_loss")

# %%
df_income.withColumnsRenamed({"capital.gain":"captial_gain","capital.loss":"capital_loss"})

# %%
df_renamed.display()

# %%
df_income.filter("sex='Male' and race='Asian-Pac-Islander'").display()

# %%
df_income.where("sex='Male'")

# %%
from pyspark.sql.functions import *

# %%
df_income.withColumn("ingestion_ts",current_timestamp()).withColumn("env",lit("dev")).withColumn("file_path",col("_metadata.file_path"))

# %%
df_income\
.withColumn("ingestion_ts",current_timestamp())\
.withColumn("env",lit("dev"))\
.withColumn("file_path",col("_metadata.file_path"))

# %%
(
df_income
 .withColumn("ingestion_ts",current_timestamp())
 .withColumn("env",lit("dev"))
 .withColumn("file_path",col("_metadata.file_path"))
 )
