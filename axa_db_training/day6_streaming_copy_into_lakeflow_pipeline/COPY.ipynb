# %%
increamental : Data which grows over time (per hour, per day and so on) -- COPY into, Pipeline
Streaming : Data which grows over time (per sec, per min and so on) -- Structured, Autoloader , Pipeline

# %%
idempotnent(skip the file which read previously and it should read only new data ) 

Structured Streaming(python, spark) -- COPY INTO (SQL)

# %%
# Batch
df=spark.read.csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.naval_bronze.income")

# %%
# Batch
df=spark.read.csv("/Volumes/dev/naval/raw/months/",header=True,inferSchema=True)
df.write.mode("append").saveAsTable("dev.naval_bronze.sales_new")

# %%
# Streaming
df=spark.readStream.csv("/Volumes/dev/naval/raw/months/",header=True,inferSchema=True)

# %%
# %sql
select distinct * from dev.naval_bronze.sales_new

# %%
# %sql
desc history dev.naval_bronze.sales_new

# %%
# %sql
CTAS or CRTAS --- Batch 
COPY INTO --- increamental

# %% [markdown]
# ## COPY INTO
#
# CREATE TABLE IF NOT EXISTS <catalog>.<schema>.booking_updates_schemaless;
#
# - COPY INTO <catalog>.<schema>.booking_updates_schemaless
# - FROM '/Volumes/<catalog>/<schema>/<volume>/wanderbricks/booking_updates'
# - FILEFORMAT = JSON
# - FORMAT_OPTIONS ('mergeSchema' = 'true', 'multiLine' = 'true')
# - COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
CREATE TABLE dev.naval_bronze.sales_incremental;

# %%
# %sql
# Batch
df=spark.read.csv("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.naval_bronze.income")

# %%
# %sql
CREATE TABLE if not EXISTS dev.naval_bronze.sales_incremental;

COPY INTO dev.naval_bronze.sales_incremental
FROM '/Volumes/dev/naval/raw/months/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
--drop table dev.naval_bronze.sales_incremental

# %%
# %sql
select * from dev.naval_bronze.sales_incremental

# %%
# %sql
desc history dev.naval_bronze.sales_incremental
