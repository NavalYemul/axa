# %%
data modelling (ER diagram)
federation
open sharing (Delta sharing)

# %%
azure sql
snowflake
redshift             (federation= making a connection) (lakeflow connect= ingestion/migration )                 databricks 
synapse 
databricks 


Anology

hdfc
sbi                               phonepe/g pay/ paytm
icici
