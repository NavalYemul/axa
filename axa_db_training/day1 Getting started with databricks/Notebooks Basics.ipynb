-- %% [markdown]
-- #Getting familiar with Databricks Notebooks

-- %%
select "RUN SQL"

-- %%
select * from samples.tpch.customer

-- %%
use catalog samples;
use schema tpch;

-- %%
select * from bakehouse.sales_transactions

-- %%
select * from orders

-- %%
select * from samples.bakehouse.sales_customers
