-- %%
grant privilege on object object_name to users

revoke privilege on object object_name from users

-- %%
revoke all privileges on table prod.bronze.sales from da;

revoke all privileges on volume prod.bronze.raw from dataeng;

-- %%
grant use catalog on catalog prod to `account users`;
grant use schema on schema prod.bronze to `account users`;
grant select on table prod.bronze.sales to `account users`;
