-- %%
Types of computes
1. All Purpose
2. Job 
3. Serverless SQL warehouse
4. Serverless (notebook)

-- %%
select "Run sql"

-- %%
%python
print("run python")

-- %%
Spark Architecture

-- %%
%python
print("hello")

-- %%
5+6
