-- %%
github
1. new repo(public) and copy the repo url-- Done


databricks
1. new git folder using the above url -- done
2.add the folder to git folder --done 
3. config between databricks and github  and commit and push

-- %%
lakeflow connect is done 
git intergration is done
