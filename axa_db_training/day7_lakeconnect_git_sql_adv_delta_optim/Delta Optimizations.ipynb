-- %%
Delta Optimization
-- Improve Query 
- Optimize
- z order
- Liquid clustering (no partition ,no  z order)

-- Reduce storage
- Vacuum

-- %%
small tiny file = large file 

optimize dev.naval.alpha

-- %%
optimize dev.naval.alpha
zorder by (id)

-- %%
select * from dev.naval.alpha

-- %%
select * from dev.naval.alpha

-- %%
desc history dev.naval.alpha

-- %%
desc extended dev.naval.alpha

-- %%
select * from dev.naval.alpha version as of 22

-- %%
desc detail dev.naval.alpha

-- %%
optimize dev.naval.alpha;

-- %%
ALTER TABLE dev.naval.alpha CLUSTER BY AUTO;

-- %%
vacuum dev.naval.alpha

-- rentention period of vacuum is 7 days= 168 hours

-- %%
vacuum dev.naval.alpha retain 0 hours

-- %%
ALTER TABLE dev.naval.alpha SET TBLPROPERTIES ('delta.deletedFileRetentionDuration' = 'interval 0 hours')

-- %%
vacuum dev.naval.alpha retain 0 hours
