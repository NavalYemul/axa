-- %%
--create catalog if not exists dev;
create schema if not exists dev.naval_bronze;
create schema if not exists dev.naval_silver;
create schema if not exists dev.naval_gold;

create volume if not exists dev.naval_bronze.raw;

--create catalog if not exists prod;
create schema if not exists prod.naval_bronze;
create schema if not exists prod.naval_silver;
create schema if not exists prod.naval_gold;

create volume if not exists prod.naval_bronze.raw;

-- %%
%python
dbutils.widgets.text("catalog","")
catalog=dbutils.widgets.get("catalog")

-- %%
%python
input_path=f"/Volumes/{catalog}/naval_bronze/raw/"

-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
def add_ingestion_metadata(df):
  return df.withColumn("ingestion_date",current_timestamp()).withColumn("file_name",col("_metadata.file_name")).withColumn("last_modified_ts",col("_metadata.file_modification_time")).withColumn("file_path",col("_metadata.file_path"))
